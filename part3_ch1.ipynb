# %%
import pandas as pd
from scipy import stats

# %%
df = pd.DataFrame({
    'weights':[122, 121, 120, 119, 125, 115, 121, 118, 117, 127,
           123, 129, 119, 124, 114, 126, 122, 124, 121, 116,
           120, 123, 127, 118, 122, 117, 124, 125, 123, 121],
})

t_statistics, p_value = stats.ttest_1samp(df['weights'], 120, alternative='less')
t_statistics, p_value
# Out:
# (np.float64(2.1155384372682344), np.float64(0.9784535214666953))
